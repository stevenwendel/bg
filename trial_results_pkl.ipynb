# %%
filepath="results/bayes_20250620_220309/trial_results.pkl"

import pickle
with open(filepath, "rb") as f:
    trial_results = pickle.load(f)

print(trial_results)
# Out:
# [{'cfg': {'POP_SIZE': 735, 'NUM_GENERATIONS': 68, 'MUT_RATE': 0.674890850875338, 'MUT_SIGMA': 0.3605996694044349, 'ELITE_SIZE': 10, 'DNA_BOUNDS': [0, 500], 'RANK_DEPTH': 367}, 'score': 667, 'dna': [3, 389, 282, 181, -418, -385, -5, -192, -389, -11, -500, -160, -130, -317, -212, -207, -222, -500, -209, 483, 140, 4, 374, 145, 328, 302, 105, 130, -288, -464, -407, 350, 258, 325, 94, 47, 266, 394, -48, -170, -301, -423, -500, -52, 329, 288, -197, -387, 111, 401, 32, 155, 287]}, {'cfg': {'POP_SIZE': 715, 'NUM_GENERATIONS': 69, 'MUT_RATE': 0.9734568508409411, 'MUT_SIGMA': 1.3467920648021974, 'ELITE_SIZE': 10, 'DNA_BOUNDS': [0, 500], 'RANK_DEPTH': 357}, 'score': 655, 'dna': [54, 40, 419, 16, -500, -500, -500, -500, -500, -5, -500, -500, -500, -500, -500, -500, -201, -500, -500, 9, 126, 35, 131, 36, 60, 59, 21, 74, -379, -500, -500, 29, 99, 36, 141, 33, 9, 59, -500, -500, -350, -500, -500, -500, 42, 25, -431, -500, 19, 121, 23, 7, 92]}, {'cfg': {'POP_SIZE': 617, 'NUM_GENERATIONS': 81, 'MUT_R
# ...
