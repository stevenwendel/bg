# %%
import pickle

results = "/Users/stevenwendel/Documents/GitHub/bg/results/adaptive_tmax_fixed_epochs_H_progressive_20250809_073827/aggregated_results.pkl"
# Out:
# Failed to start the Kernel.
#
# The kernel died. Error: ... View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print('hi')
with open(results, "rb") as file:
    data = pickle.load(file)
